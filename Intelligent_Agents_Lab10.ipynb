# %% [markdown]
# <a href="https://colab.research.google.com/github/Ubanman0135/COMP2009-Lab10/blob/main/Intelligent_Agents_Lab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install numpy pandas
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a5a8f7f-0623-48be-b5e0-46f639e91ead" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a5a8f7f-0623-48be-b5e0-46f639e91ead">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
# Out:
# drive  sample_data  test.txt

# %%
# url = "https://colab.research.google.com/sample_data/california_housing_train.csv"
# headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/148.0.0.0 Safari/537.36'}
# df = pd.read_csv(url, storage_options=headers)

# %%
x = np.array([1, 2, 3])
print(x * x)
# Out:
# [1 4 9]

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = [1, 4, 9]
plt.plot(x, y)
plt.title("Sample Plot")
plt.show()

# %%
with open('/content/drive/MyDrive/output.txt', 'w') as f:
  f.write("Saved to Drive")

# %%
# !ls /content/drive/MyDrive/
# Out:
# 'Colab Notebooks'   output.txt

# %%
from google.colab import files
files.download('/content/drive/MyDrive/output.txt')

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
